# %%
# !pip install mlxtend pyECLAT efficient-apriori plotly
# !pip install sweetviz lux-api autoviz plotly matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.0/127.0 kB 4.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 47.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 62.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.5/67.5 kB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.2/161.2 kB 11.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.9/255.9 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 586.9/586.9 kB 27.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 53.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 48.8 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import json
import seaborn as sns
import sweetviz as sv
import lux
from autoviz import AutoViz_Class
import plotly.express as px
import matplotlib.pyplot as plt
# %matplotlib inline

DATA = pd.read_csv('drive/MyDrive/Comune-di-Milano-Pubblici-esercizi.csv',sep=';',encoding='utf-16')
DATA


#http://www.datiopen.it/it/opendata/Comune_di_Milano_Pubblici_esercizi
# Out:
# Imported v0.1.905. Please call AutoViz in this sequence:
#     AV = AutoViz_Class()
#     %matplotlib inline
#     dfte = AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=1, lowess=False,
#                chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30, save_plot_dir=None)
#         Tipo esercizio storico pe          Insegna         \
# 0                                NaN                  NaN
# 1                                NaN                  NaN
# 2                                NaN                  NaN
# 3                                NaN                  NaN
# 4                                NaN                  NaN
# ...                              ...                  ...
# 6899  wine,birr.,pub enot.,caff.,the           bar cherry
# 6900  wine,birr.,pub enot.,caff.,the            la balusa
# 6901  wine,birr.,pub enot.,caff.,the  la champagnerie sas
# 6902  wine,birr.,pub enot.,caff.,the          old rooster
# ...

# %% [markdown]
# ##*Data Exploration*
# Data quality assessment checks

# %%
#Data schema
DATA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6904 entries, 0 to 6903
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Tipo esercizio storico pe    5551 non-null   object
#  1   Insegna                      3494 non-null   object
#  2   Ubicazione                   6904 non-null   object
#  3   Tipo via                     6904 non-null   object
#  4   Descrizione via              6904 non-null   object
#  5   Civico                       6748 non-null   object
#  6   Codice via                   6904 non-null   int64
#  7   ZD                           6904 non-null   int64
#  8   Forma commercio              5333 non-null   object
#  9   Forma commercio prev         5507 non-null   object
#  10  Forma vendita                5480 non-null   object
#  11  Settore storico pe           6883 non-null   object
#  12  Superficie somministrazione  6825 non-null   float64
# ...

# %%
#other information of the integer of the schema
DATA.describe()
# Out:
#         Codice via           ZD  Superficie somministrazione
# count  6904.000000  6904.000000                  6825.000000
# mean   3555.016367     4.573001                    85.996777
# std    2238.982545     2.763538                    89.676674
# min       1.000000     1.000000                     2.000000
# 25%    1510.000000     2.000000                    42.000000
# 50%    3129.000000     4.000000                    64.000000
# 75%    5294.000000     7.000000                   100.000000
# max    7602.000000     9.000000                  2336.000000

# %%
#Information about the type of esercizio
DATA.value_counts("Tipo esercizio storico pe")
# Out:
# Tipo esercizio storico pe
# bar caff�                         3274
# ristorante                         807
# trattoria                          554
# pizzeria                           350
# tavola calda                       104
# spaccio bevande analcoliche         82
# ristorante, trattoria, osteria      62
# bar gastronomici e simili           49
# gelateria                           48
# osteria                             38
# tavola fredda                       34
# bar-caffe' e simili                 30
# genere merceol.autorizz.sanit.      27
# birreria                            21
# pizzerie e simili                   16
# bar pasticc.gelat.crem.creper.      11
# tav.calde,self service,fast f.      10
# cibi cotti                          10
# prodotti di gastronomia              7
# cibi cotti preconfezionati           7
# wine,birr.,pub enot.,caff.,the       5
# sale da ballo, locali notturni       4
# mensa                                1
# Name: count, dtype: int64

# %% [markdown]
# **Duplication evaluation**

# %%
#Show the duplicates if there are some
DATA[DATA.duplicated()]
# Out:
#     Tipo esercizio storico pe Insegna                  Ubicazione Tipo via  \
# 940                       NaN     NaN  VIA SALASCO N. 29 (z.d. 5)      VIA
#
#     Descrizione via Civico  Codice via  ZD Forma commercio  \
# 940         SALASCO     29        4051   5             NaN
#
#     Forma commercio prev Forma vendita           Settore storico pe  \
# 940                  NaN           NaN  Spaccio bevande analcoliche
#
#      Superficie somministrazione
# 940                          NaN

# %%
#use for check in the duplication part
#shows if there are duplicates
#print(DATA.duplicated().any())
#print(DATA.duplicated().sum())

# %% [markdown]
# **Completeness evaluation**

# %%
#display the number of null values for each column
#it can be useful for understanding the data we are analyzing
DATA.isnull().sum()
# Out:
# Tipo esercizio storico pe      1353
# Insegna                        3410
# Ubicazione                        0
# Tipo via                          0
# Descrizione via                   0
# Civico                          156
# Codice via                        0
# ZD                                0
# Forma commercio                1571
# Forma commercio prev           1397
# Forma vendita                  1424
# Settore storico pe               21
# Superficie somministrazione      79
# dtype: int64

# %%
#Display the completeness for each column
NULL_VALUES = DATA.isnull().sum()
NOT_NULL_VALUES = DATA.notnull().sum()
N_ROWS = DATA.shape[0]
COMPLETENESS = NOT_NULL_VALUES / N_ROWS*100
print(COMPLETENESS)
# Out:
# Tipo esercizio storico pe       80.402665
# Insegna                         50.608343
# Ubicazione                     100.000000
# Tipo via                       100.000000
# Descrizione via                100.000000
# Civico                          97.740440
# Codice via                     100.000000
# ZD                             100.000000
# Forma commercio                 77.245075
# Forma commercio prev            79.765353
# Forma vendita                   79.374276
# Settore storico pe              99.695829
# Superficie somministrazione     98.855736
# dtype: float64

# %%
#we need to understand how much is the db complete
TOT_NULL_VALUES = DATA.isnull().sum().sum()
TOT_NOT_NULL_VALUES = DATA.notnull().sum().sum()
TOT_TOTAL = DATA.shape[0]*DATA.shape[1]
TOT_COMPLETENESS = '{0:.1f}%'.format(TOT_NOT_NULL_VALUES / TOT_TOTAL *100)
print(TOT_COMPLETENESS)
# Out:
# 89.5%

# %% [markdown]
# **Accuracy evaluation...**

# %% [markdown]
# **Timeliness evaluation...**

# %% [markdown]
# **Consistency evaluation...**

# %% [markdown]
# ##*Data Profiling*
# Data quality assessment checks

# %% [markdown]
# **Single column analisys: Cardinalities**
#
# Cardinalities are numbers that summarize simple metadata (*e.g.,* number of rows, attributes, null values, distinct values, Uniqueness and Distinctness).
#
# *Cardinality* = count of the number of distinct actual values.
#
# *Uniqueness* = percentage calculated as Cardinality divided by the total number of records.
#
# *Actual* = count of the number of records with an actual value (*i.e.,* not-null).
#
# *Distinctness* = percentage calculated as Cardinality divided by Actual.

# %%
#count the number of distinct values for each column
DISTINCT = DATA.nunique()
print(DISTINCT)
# Out:
# Tipo esercizio storico pe        23
# Insegna                        2882
# Ubicazione                     6322
# Tipo via                         16
# Descrizione via                1840
# Civico                          263
# Codice via                     1856
# ZD                                9
# Forma commercio                   2
# Forma commercio prev              2
# Forma vendita                     4
# Settore storico pe             3975
# Superficie somministrazione     400
# dtype: int64
# Tipo esercizio storico pe      0.003331
# Insegna                        0.417439
# Ubicazione                     0.915701
# Tipo via                       0.002317
# Descrizione via                0.266512
# Civico                         0.038094
# Codice via                     0.268830
# ZD                             0.001304
# Forma commercio                0.000290
# Forma commercio prev           0.000290
# Forma vendita                  0.000579
# ...

# %%
#uniqueness value of each column
UNIQUENESS = DISTINCT / N_ROWS * 100
print(UNIQUENESS)
# Out:
# Tipo esercizio storico pe       0.333140
# Insegna                        41.743917
# Ubicazione                     91.570104
# Tipo via                        0.231750
# Descrizione via                26.651217
# Civico                          3.809386
# Codice via                     26.882966
# ZD                              0.130359
# Forma commercio                 0.028969
# Forma commercio prev            0.028969
# Forma vendita                   0.057937
# Settore storico pe             57.575319
# Superficie somministrazione     5.793743
# dtype: float64

# %%
#number of not null values of each column
DATA.count()
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
#disctinctness value of each column
COUNT = DATA.count()
DISTINCTNESS = DISTINCT / COUNT
print(DISTINCTNESS)
# Out:
# Tipo esercizio storico pe      0.004143
# Insegna                        0.824843
# Ubicazione                     0.915701
# Tipo via                       0.002317
# Descrizione via                0.266512
# Civico                         0.038975
# Codice via                     0.268830
# ZD                             0.001304
# Forma commercio                0.000375
# Forma commercio prev           0.000363
# Forma vendita                  0.000730
# Settore storico pe             0.577510
# Superficie somministrazione    0.058608
# dtype: float64

# %%
#extremes (attribute "Superficie somministrazione")
print ('MIN:', DATA['Superficie somministrazione'].min())
print ('MAX:', DATA['Superficie somministrazione'].max())
print ('MODE:', DATA['Superficie somministrazione'].mode()[0])
# Out:
# MIN: 2.0
# MAX: 2336.0
# MODE: 60.0

# %%
#show the "esercizi storici" that have the min "superficie somministrazione"
DATA[DATA['Superficie somministrazione'] == DATA['Superficie somministrazione'].min()]
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
#show the "esercizi storici" that have the max "superficie somministrazione"
DATA[DATA['Superficie somministrazione'] == DATA['Superficie somministrazione'].max()]
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
#other information: Mean and Standard deviation
print('Average:', DATA['Superficie somministrazione'].mean())
print('Standard Deviation:', DATA['Superficie somministrazione'].std())
# Out:
# Average: 85.99677655677655
# Standard Deviation: 89.67667427982182

# %%
#plot the distribution of the attribute "Superficie somministrazione" with hist function
DATA['Superficie somministrazione'].hist()
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %% [markdown]
# **SWEET REPORT**,
# useful for visualizing our data

# %%
sweet_report = sv.analyze([DATA,'Sweetviz Report'])
sweet_report.show_notebook()
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.7.1 | (c) OpenJS Foundation and other contributors | jquery.org/license */
# ...

# %%
DATA
# Out:
#         Tipo esercizio storico pe          Insegna         \
# 0                                NaN                  NaN
# 1                                NaN                  NaN
# 2                                NaN                  NaN
# 3                                NaN                  NaN
# 4                                NaN                  NaN
# ...                              ...                  ...
# 6899  wine,birr.,pub enot.,caff.,the           bar cherry
# 6900  wine,birr.,pub enot.,caff.,the            la balusa
# 6901  wine,birr.,pub enot.,caff.,the  la champagnerie sas
# 6902  wine,birr.,pub enot.,caff.,the          old rooster
# 6903  wine,birr.,pub enot.,caff.,the            starhotel
#
#                                         Ubicazione                                    \
# 0                                  ALZ NAVIGLIO GRANDE N. 12 ; isolato:057; (z.d. 6)
# 1                                                 ALZ NAVIGLIO GRANDE N. 44 (z.d. 6)
# ...

# %%
DATA.value_counts("Forma commercio")
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
DATA.value_counts("Forma commercio prev")
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
DATA.value_counts("Forma vendita")
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()
